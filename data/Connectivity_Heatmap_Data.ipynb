# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Robinson_Heatmap_Data.csv')

# %%
df
# Out:
#       nu_rs  -0.0009  -0.00089  -0.00088  -0.00087   -0.00086  -0.00085
# 0   0.00000      0.0       0.0  9.295014  9.269108  47.831541  9.981743  \
# 1   0.00001      0.0       0.0  0.000000  9.342581   9.326363  9.245679
# 2   0.00002      0.0       0.0  0.000000  9.416847   9.147095  9.191822
# 3   0.00003      0.0       0.0  0.000000  0.000000   9.458857  9.208617
# 4   0.00004      0.0       0.0  0.000000  0.000000   0.000000  9.497509
# 5   0.00005      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 6   0.00006      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 7   0.00007      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 8   0.00008      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 9   0.00009      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 10  0.00010      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 11  0.00011      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# ...

# %%
df.set_index('nu_rs', inplace=True)
df
# Out:
#          -0.0009  -0.00089  -0.00088  -0.00087   -0.00086  -0.00085
# nu_rs
# 0.00000      0.0       0.0  9.295014  9.269108  47.831541  9.981743  \
# 0.00001      0.0       0.0  0.000000  9.342581   9.326363  9.245679
# 0.00002      0.0       0.0  0.000000  9.416847   9.147095  9.191822
# 0.00003      0.0       0.0  0.000000  0.000000   9.458857  9.208617
# 0.00004      0.0       0.0  0.000000  0.000000   0.000000  9.497509
# 0.00005      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00006      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00007      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00008      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00009      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00010      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00011      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# 0.00012      0.0       0.0  0.000000  0.000000   0.000000  0.000000
# ...

# %%
ax = sns.heatmap(df, vmax=12)
ax.invert_yaxis()
ax.invert_xaxis()

# %%
df_Liley= pd.read_csv('Liley_EI_connection.csv', header =0, index_col=0)

# %%
ax = sns.heatmap(df_Liley, vmax=12)
ax.invert_yaxis()

# %%
df_Jansen = pd.read_csv('Jansen_Rit_EI_connection.csv', header =0, index_col=0)

# %%
ax = sns.heatmap(df_Jansen, vmax=12)
ax.invert_yaxis()

# %%
0.52*135
# Out:
# 70.2
